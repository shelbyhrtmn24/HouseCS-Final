# %% [markdown]
# We are going to examine a Variational Quantum Classifier on the Mushroom Classification Kaggle dataset.

# %%
#To start, we import all essential packages.

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from qiskit.circuit.library import ZZFeatureMap
from qiskit.circuit.library import RealAmplitudes
from qiskit.algorithms.optimizers import COBYLA
from matplotlib import pyplot as plt
from IPython.display import clear_output
import time
from sklearn.decomposition import PCA
from qiskit.circuit.library import EfficientSU2
from qiskit import *

# %%
#Let's import the data and take a preliminary look at the feature space.
df = pd.read_csv("data/mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
#In order to better handle the large amount of categorical variables, we will use label encodings. This encodes the categories as numbers.
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in df.columns:
    df[col] = encoder.fit_transform(df[col])
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
#Now, we are going to divide the dataset into our features and our labels. 
X = df.iloc[:, 1:23]
y = df.iloc[:, 0]

X.head() #These are our features
y.head() #These are our labels
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
#Let's try some exploratory data analysis to better familiarize ourselves with the feature space.
X.corr()
# Out:
#                           cap-shape  cap-surface  cap-color   bruises  \
# cap-shape                  1.000000    -0.050454  -0.048203 -0.035374
# cap-surface               -0.050454     1.000000  -0.019402  0.070228
# cap-color                 -0.048203    -0.019402   1.000000 -0.000764
# bruises                   -0.035374     0.070228  -0.000764  1.000000
# odor                      -0.021935     0.045233  -0.387121 -0.061825
# gill-attachment            0.078865    -0.034180   0.041436  0.137359
# gill-spacing               0.013196    -0.282306   0.144259 -0.299473
# gill-size                  0.054050     0.208100  -0.169464 -0.369596
# gill-color                -0.006039    -0.161017   0.084659  0.527120
# stalk-shape                0.063794    -0.014123  -0.456496  0.099364
# stalk-root                 0.030191    -0.126245   0.321274  0.244188
# stalk-surface-above-ring  -0.030417     0.089090  -0.060837  0.460824
# stalk-surface-below-ring  -0.032591     0.107965  -0.047710  0.458983
# stalk-color-above-ring    -0.031659     0.066050   0.002364  0.083538
# stalk-color-below-ring    -0.030390     0.068885   0.008057  0.092874
# veil-type                       NaN          NaN        NaN       NaN
# veil-color                 0.072560    -0.016603   0.036130  0.119770
# ring-number               -0.106534    -0.026147  -0.005822  0.056788
# ring-type                 -0.025457    -0.106407   0.162513  0.692973
# spore-print-color         -0.073416     0.230364  -0.293523 -0.285008
# population                 0.063413     0.021555  -0.144770  0.088137
# habitat                   -0.042221     0.163887   0.033925 -0.075095
#
#                               odor  gill-attachment  gill-spacing  gill-size  \
# cap-shape                -0.021935         0.078865      0.013196   0.054050
# cap-surface               0.045233        -0.034180     -0.282306   0.208100
# cap-color                -0.387121         0.041436      0.144259  -0.169464
# bruises                  -0.061825         0.137359     -0.299473  -0.369596
# odor                      1.000000        -0.059590      0.063936   0.310495
# gill-attachment          -0.059590         1.000000      0.071489   0.108984
# gill-spacing              0.063936         0.071489      1.000000  -0.108333
# gill-size                 0.310495         0.108984     -0.108333   1.000000
# gill-color               -0.129213        -0.128567      0.100193  -0.516736
# stalk-shape               0.459766         0.186485      0.080895   0.214576
# stalk-root               -0.205215         0.144063      0.350548  -0.344345
# stalk-surface-above-ring  0.118617        -0.088916     -0.212359   0.056310
# stalk-surface-below-ring  0.061820        -0.116177     -0.213775   0.010894
# stalk-color-above-ring    0.174532         0.099299      0.274574   0.296548
# stalk-color-below-ring    0.169407         0.097160      0.253505   0.278708
# veil-type                      NaN              NaN           NaN        NaN
# veil-color               -0.057747         0.897518      0.073363   0.103809
# ring-number               0.111905         0.093236      0.243014  -0.171362
# ring-type                -0.281387        -0.146689     -0.195897  -0.460872
# spore-print-color         0.469055        -0.029524      0.047323   0.622991
# population               -0.043623         0.165575     -0.529253   0.147682
# habitat                  -0.026610        -0.030304     -0.154680   0.161418
#
#                           gill-color  stalk-shape  ...  \
# cap-shape                  -0.006039     0.063794  ...
# cap-surface                -0.161017    -0.014123  ...
# cap-color                   0.084659    -0.456496  ...
# bruises                     0.527120     0.099364  ...
# odor                       -0.129213     0.459766  ...
# gill-attachment            -0.128567     0.186485  ...
# gill-spacing                0.100193     0.080895  ...
# gill-size                  -0.516736     0.214576  ...
# gill-color                  1.000000    -0.175699  ...
# stalk-shape                -0.175699     1.000000  ...
# stalk-root                  0.315080    -0.163422  ...
# stalk-surface-above-ring    0.224287     0.015193  ...
# stalk-surface-below-ring    0.257224    -0.034399  ...
# stalk-color-above-ring     -0.058299     0.223439  ...
# stalk-color-below-ring     -0.074781     0.235794  ...
# veil-type                        NaN          NaN  ...
# veil-color                 -0.097583     0.162604  ...
# ring-number                 0.096054    -0.293221  ...
# ring-type                   0.629398    -0.291444  ...
# spore-print-color          -0.416135     0.258831  ...
# population                 -0.034090     0.087383  ...
# habitat                    -0.202972    -0.269216  ...
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# cap-shape                                -0.032591               -0.031659
# cap-surface                               0.107965                0.066050
# cap-color                                -0.047710                0.002364
# bruises                                   0.458983                0.083538
# odor                                      0.061820                0.174532
# gill-attachment                          -0.116177                0.099299
# gill-spacing                             -0.213775                0.274574
# gill-size                                 0.010894                0.296548
# gill-color                                0.257224               -0.058299
# stalk-shape                              -0.034399                0.223439
# stalk-root                                0.087454                0.157140
# stalk-surface-above-ring                  0.437164                0.132708
# stalk-surface-below-ring                  1.000000                0.106933
# stalk-color-above-ring                    0.106933                1.000000
# stalk-color-below-ring                    0.110656                0.491510
# veil-type                                      NaN                     NaN
# veil-color                               -0.077284                0.067377
# ring-number                               0.040006                0.084917
# ring-type                                 0.394644               -0.048878
# spore-print-color                         0.130974                0.271533
# population                                0.046797               -0.240261
# habitat                                  -0.039628                0.042561
#
#                           stalk-color-below-ring  veil-type  veil-color  \
# cap-shape                              -0.030390        NaN    0.072560
# cap-surface                             0.068885        NaN   -0.016603
# cap-color                               0.008057        NaN    0.036130
# bruises                                 0.092874        NaN    0.119770
# odor                                    0.169407        NaN   -0.057747
# gill-attachment                         0.097160        NaN    0.897518
# gill-spacing                            0.253505        NaN    0.073363
# gill-size                               0.278708        NaN    0.103809
# gill-color                             -0.074781        NaN   -0.097583
# stalk-shape                             0.235794        NaN    0.162604
# stalk-root                              0.159805        NaN    0.156213
# stalk-surface-above-ring                0.142835        NaN   -0.090591
# stalk-surface-below-ring                0.110656        NaN   -0.077284
# stalk-color-above-ring                  0.491510        NaN    0.067377
# stalk-color-below-ring                  1.000000        NaN    0.065567
# veil-type                                    NaN        NaN         NaN
# veil-color                              0.065567        NaN    1.000000
# ring-number                             0.087580        NaN    0.036380
# ring-type                              -0.034284        NaN   -0.143673
# spore-print-color                       0.254518        NaN   -0.003600
# population                             -0.242792        NaN    0.124924
# habitat                                 0.041594        NaN   -0.040581
#
#                           ring-number  ring-type  spore-print-color  \
# cap-shape                   -0.106534  -0.025457          -0.073416
# cap-surface                 -0.026147  -0.106407           0.230364
# cap-color                   -0.005822   0.162513          -0.293523
# bruises                      0.056788   0.692973          -0.285008
# odor                         0.111905  -0.281387           0.469055
# gill-attachment              0.093236  -0.146689          -0.029524
# gill-spacing                 0.243014  -0.195897           0.047323
# gill-size                   -0.171362  -0.460872           0.622991
# gill-color                   0.096054   0.629398          -0.416135
# stalk-shape                 -0.293221  -0.291444           0.258831
# stalk-root                  -0.247357   0.210155          -0.536996
# stalk-surface-above-ring     0.107904   0.390091           0.100764
# stalk-surface-below-ring     0.040006   0.394644           0.130974
# stalk-color-above-ring       0.084917  -0.048878           0.271533
# stalk-color-below-ring       0.087580  -0.034284           0.254518
# veil-type                         NaN        NaN                NaN
# veil-color                   0.036380  -0.143673          -0.003600
# ring-number                  1.000000   0.058312           0.338417
# ring-type                    0.058312   1.000000          -0.487048
# spore-print-color            0.338417  -0.487048           1.000000
# population                  -0.242020   0.211763          -0.126859
# habitat                      0.235835  -0.212080           0.185954
#
#                           population   habitat
# cap-shape                   0.063413 -0.042221
# cap-surface                 0.021555  0.163887
# cap-color                  -0.144770  0.033925
# bruises                     0.088137 -0.075095
# odor                       -0.043623 -0.026610
# gill-attachment             0.165575 -0.030304
# gill-spacing               -0.529253 -0.154680
# gill-size                   0.147682  0.161418
# gill-color                 -0.034090 -0.202972
# stalk-shape                 0.087383 -0.269216
# stalk-root                 -0.306747 -0.007668
# stalk-surface-above-ring    0.079604 -0.058076
# stalk-surface-below-ring    0.046797 -0.039628
# stalk-color-above-ring     -0.240261  0.042561
# stalk-color-below-ring     -0.242792  0.041594
# veil-type                        NaN       NaN
# veil-color                  0.124924 -0.040581
# ring-number                -0.242020  0.235835
# ring-type                   0.211763 -0.212080
# spore-print-color          -0.126859  0.185954
# population                  1.000000 -0.174529
# habitat                    -0.174529  1.000000
#
# [22 rows x 22 columns]

# %%
X.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     2.000000     0.000000
# 50%           1.000000      0.000000     0.000000     5.000000     1.000000
# 75%           1.000000      0.000000     1.000000     7.000000     1.000000
# max           1.000000      1.000000     1.000000    11.000000     1.000000
#
#        ...  stalk-surface-below-ring  stalk-color-above-ring  \
# count  ...               8124.000000             8124.000000
# mean   ...                  1.603644                5.816347
# std    ...                  0.675974                1.901747
# min    ...                  0.000000                0.000000
# 25%    ...                  1.000000                6.000000
# 50%    ...                  2.000000                7.000000
# 75%    ...                  2.000000                7.000000
# max    ...                  3.000000                8.000000
#
#        stalk-color-below-ring  veil-type   veil-color  ring-number  \
# count             8124.000000     8124.0  8124.000000  8124.000000
# mean                 5.794682        0.0     1.965534     1.069424
# std                  1.907291        0.0     0.242669     0.271064
# min                  0.000000        0.0     0.000000     0.000000
# 25%                  6.000000        0.0     2.000000     1.000000
# 50%                  7.000000        0.0     2.000000     1.000000
# 75%                  7.000000        0.0     2.000000     1.000000
# max                  8.000000        0.0     3.000000     2.000000
#
#          ring-type  spore-print-color   population      habitat
# count  8124.000000        8124.000000  8124.000000  8124.000000
# mean      2.291974           3.596750     3.644018     1.508616
# std       1.801672           2.382663     1.252082     1.719975
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           2.000000     3.000000     0.000000
# 50%       2.000000           3.000000     4.000000     1.000000
# 75%       4.000000           7.000000     4.000000     2.000000
# max       4.000000           8.000000     5.000000     6.000000
#
# [8 rows x 22 columns]

# %%
#There are a relatively large number of features. We suspect that not all will be necessary. Let's implement a quick PCA to reduce the dimensionality of our dataset.
X = PCA(n_components = 4).fit_transform(X) #we get 4 in order to require few qubits in our quantum simulation
X
# Out:
# array([[ 0.22820662, -0.34547171, -1.4244231 , -1.2467113 ],
#        [-1.93656097,  4.79691194, -3.51166873, -1.2457248 ],
#        [-1.65417317,  2.46436214, -3.88082782,  1.22250081],
#        ...,
#        [-1.86050705,  0.47024364,  1.19021172, -0.30658025],
#        [ 7.29306843, -1.25169239, -1.24197539,  0.78174419],
#        [-4.83553281, -3.58375785, -0.11250493,  2.51763783]])

# %%
#Now, we are going to split our dataset into a training set and testing set. The testing set will be used to measure the accuracy of our results before submitting.
from qiskit.utils import algorithm_globals
from sklearn.model_selection import train_test_split

algorithm_globals.random_seed = 123
train_features, test_features, train_labels, test_labels = train_test_split(
    X, y, train_size=0.8, random_state=algorithm_globals.random_seed
)

# %%
#We now need to implement the SVC and VQC to compare our standard classical algorithm with a quantum counterpart.
from sklearn.svm import SVC
svc = SVC()
_ = svc.fit(train_features, train_labels)

# %%
train_score = svc.score(train_features, train_labels)
test_score = svc.score(test_features, test_labels)

print(f"Classical SVC on the training dataset: {train_score:.2f}")
print(f"Classical SVC on the test dataset:     {test_score:.2f}")
# Out:
# Classical SVC on the training dataset: 0.93
# Classical SVC on the test dataset:     0.92

# %% [markdown]
# To make predictions on our dataset with a VQC, we need to leverage a quantum feature map. This map is how we convert our classically maintained dataset into quantum information that can be processed by a quantum algorithm. Some examples are as follows:

# %%
from qiskit.circuit.library import ZZFeatureMap

num_features = X.shape[1]

fmap = ZZFeatureMap(feature_dimension=num_features, reps=1)
fmap.decompose().draw(output = 'mpl', fold=20)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\qiskit\circuit\tools\pi_check.py:49: SymPyDeprecationWarning:
#
# The expr_free_symbols property is deprecated. Use free_symbols to get
# the free symbols of an expression.
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#deprecated-expr-free-symbols
# for details.
#
# This has been deprecated since SymPy version 1.9. It
# will be removed in a future version of SymPy.
#
#   if not hasattr(inpt._symbol_expr, "expr_free_symbols"):
# C:\Users\joshu\anaconda3\lib\site-packages\sympy\core\expr.py:2442: SymPyDeprecationWarning:
#
# The expr_free_symbols property is deprecated. Use free_symbols to get
# the free symbols of an expression.
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#deprecated-expr-free-symbols
# for details.
#
# This has been deprecated since SymPy version 1.9. It
# will be removed in a future version of SymPy.
#
#   return {j for i in self.args for j in i.expr_free_symbols}

# %%
from qiskit.circuit.library import RealAmplitudes

ans = RealAmplitudes(num_qubits=num_features, reps=3)
ans.decompose().draw(output = 'mpl', fold = 20)

# %%
from qiskit.algorithms.optimizers import COBYLA

opt = COBYLA(maxiter=100)

# %%
from matplotlib import pyplot as plt
from IPython.display import clear_output

objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)


def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
from qiskit.aqua import QuantumInstance
from qiskit import Aer

backend = Aer.get_backend('qasm_simulator')
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\qiskit\aqua\__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')

# %%
import time
from qiskit_machine_learning.algorithms.classifiers import VQC

vqc = VQC(
    feature_map=fmap,
    ansatz=ans,
    optimizer=opt,
    callback=callback_graph,
    quantum_instance=backend
)


# clear objective value history
objective_func_vals = []
#print(dir(VQC))
start = time.time()
_ = vqc.fit(train_features, train_labels)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")
# Out:
# ---------------------------------------------------------------------------
# QiskitMachineLearningError                Traceback (most recent call last)
# Input In [20], in <cell line: 17>()
#      15 #print(dir(VQC))
#      16 start = time.time()
# ---> 17 vqc.fit(train_features, train_labels)
#      18 elapsed = time.time() - start
#      20 print(f"Training time: {round(elapsed)} seconds")
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\algorithms\classifiers\vqc.py:166, in VQC.fit(self, X, y)
#     162 num_classes = len(np.unique(y, axis=0))
#     163 cast(CircuitQNN, self._neural_network).set_interpret(
#     164     self._get_interpret(num_classes), num_classes
#     165 )
# --> 166 return super().fit(X, y)
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\algorithms\classifiers\neural_network_classifier.py:107, in NeuralNetworkClassifier.fit(self, X, y)
#     103         function = MultiClassObjectiveFunction(X, y, self._neural_network, self._loss)
#     105 objective = self._get_objective(function)
# --> 107 self._fit_result = self._optimizer.optimize(
#     108     self._neural_network.num_weights,
#     109     objective,
#     110     function.gradient,
#     111     initial_point=self._choose_initial_point(),
#     112 )
#     113 return self
#
# File ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\scipy_optimizer.py:140, in SciPyOptimizer.optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     131 # Validate the input
#     132 super().optimize(
#     133     num_vars,
#     134     objective_function,
#    (...)
#     137     initial_point=initial_point,
#     138 )
# --> 140 res = minimize(
#     141     fun=objective_function,
#     142     x0=initial_point,
#     143     method=self._method,
#     144     jac=gradient_function,
#     145     bounds=variable_bounds,
#     146     options=self._options,
#     147     **self._kwargs,
#     148 )
#     149 return res.x, res.fun, res.nfev
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:629, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#     628 elif meth == 'cobyla':
# --> 629     return _minimize_cobyla(fun, x0, args, constraints, **options)
#     630 elif meth == 'slsqp':
#     631     return _minimize_slsqp(fun, x0, args, jac, bounds,
#     632                            constraints, callback=callback, **options)
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\cobyla.py:34, in synchronized.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(func)
#      32 def wrapper(*args, **kwargs):
#      33     with _module_lock:
# ---> 34         return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\cobyla.py:260, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, **unknown_options)
#     257     return f
#     259 info = np.zeros(4, np.float64)
# --> 260 xopt, info = _cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     261                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     262                               dinfo=info)
#     264 if info[3] > catol:
#     265     # Check constraint violation
#     266     info[0] = 4
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\cobyla.py:252, in _minimize_cobyla.<locals>.calcfc(x, con)
#     251 def calcfc(x, con):
# --> 252     f = fun(np.copy(x), *args)
#     253     i = 0
#     254     for size, c in izip(cons_lengths, constraints):
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:227, in TrainableModel._get_objective.<locals>.objective(objective_weights)
#     226 def objective(objective_weights):
# --> 227     objective_value = function.objective(objective_weights)
#     228     self._callback(objective_weights, objective_value)
#     229     return objective_value
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\algorithms\objective_functions.py:188, in OneHotObjectiveFunction.objective(self, weights)
#     186 probs = self._neural_network_forward(weights)
#     187 # float(...) is for mypy compliance
# --> 188 return float(np.sum(self._loss(probs, self._y)))
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\utils\loss_functions\loss_functions.py:31, in Loss.__call__(self, predict, target)
#      27 def __call__(self, predict: np.ndarray, target: np.ndarray) -> np.ndarray:
#      28     """
#      29     This method calls the ``evaluate`` method. This is a convenient method to compute loss.
#      30     """
# ---> 31     return self.evaluate(predict, target)
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\utils\loss_functions\loss_functions.py:150, in CrossEntropyLoss.evaluate(self, predict, target)
#     149 def evaluate(self, predict: np.ndarray, target: np.ndarray) -> np.ndarray:
# --> 150     self._validate_shapes(predict, target)
#     151     if len(predict.shape) == 1:
#     152         predict = predict.reshape(1, -1)
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\utils\loss_functions\loss_functions.py:66, in Loss._validate_shapes(predict, target)
#      54 """
#      55 Validates that shapes of both parameters are identical.
#      56
#    (...)
#      62     QiskitMachineLearningError: shapes of predict and target do not match.
#      63 """
#      65 if predict.shape != target.shape:
# ---> 66     raise QiskitMachineLearningError(
#      67         f"Shapes don't match, predict: {predict.shape}, target: {target.shape}!"
#      68     )
#
# QiskitMachineLearningError: "Shapes don't match, predict: (6499, 2), target: (6499,)!"

# %%
train_score = vqc.score(train_features, train_labels)
test_score = vqc.score(test_features, test_labels)

print(f"Quantum VQC on the training dataset: {train_score:.2f}")
print(f"Quantum VQC on the test dataset:     {test_score:.2f}")
# Out:
# ---------------------------------------------------------------------------
# QiskitMachineLearningError                Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 train_score = vqc.score(train_features, train_labels)
#       2 test_score = vqc.score(test_features, test_labels)
#       4 print(f"Quantum VQC on the training dataset: {train_score:.2f}")
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\algorithms\classifiers\neural_network_classifier.py:136, in NeuralNetworkClassifier.score(self, X, y, sample_weight)
#     132 def score(
#     133     self, X: np.ndarray, y: np.ndarray, sample_weight: Optional[np.ndarray] = None
#     134 ) -> float:
#     135     y = self._encode_labels(y)
# --> 136     return ClassifierMixin.score(self, X, y, sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:651, in ClassifierMixin.score(self, X, y, sample_weight)
#     626 """
#     627 Return the mean accuracy on the given test data and labels.
#     628
#    (...)
#     647     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     648 """
#     649 from .metrics import accuracy_score
# --> 651 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\qiskit_machine_learning\algorithms\classifiers\neural_network_classifier.py:117, in NeuralNetworkClassifier.predict(self, X)
#     115 def predict(self, X: np.ndarray) -> np.ndarray:  # pylint: disable=invalid-name
#     116     if self._fit_result is None:
# --> 117         raise QiskitMachineLearningError("Model needs to be fit to some training data first!")
#     118     if self._neural_network.output_shape == (1,):
#     119         predict = np.sign(self._neural_network.forward(X, self._fit_result[0]))
#
# QiskitMachineLearningError: 'Model needs to be fit to some training data first!'

# %%
#We can consider the same algorithm but with a different ansatz

from qiskit.circuit.library import EfficientSU2

ansatz = EfficientSU2(num_qubits=num_features, reps=3)
optimizer = COBYLA(maxiter=40)

vqc = VQC(
    feature_map=fmap,
    ansatz=ans,
    optimizer=opt,
    callback=callback_graph,
    quantum_instance = backend
)

# clear objective value history
objective_func_vals = []

start = time.time()
_ = vqc.fit(train_features, train_labels)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")

# %%
train_score_q2_eff = vqc.score(train_features, train_labels)
test_score_q2_eff = vqc.score(test_features, test_labels)

print(f"Quantum VQC on the training dataset using EfficientSU2: {train_score_q2_eff:.2f}")
print(f"Quantum VQC on the test dataset using EfficientSU2:     {test_score_q2_eff:.2f}")
